# %% [markdown]
# <a href="https://colab.research.google.com/github/bakibillahrahat/tiny-ML/blob/main/2-3-9-AssignmentQuestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create a CNN to classify Cifar-10
#
# Learn about Cifar-10 here: https://www.cs.toronto.edu/~kriz/cifar.html
#
# In class you saw how to build a Convolutional Neural Network that classified Fashion MNIST. Take what you learned to build a CNN that recognizes the 10 classes of CIFAR. It will be a similar network, but there are some key differences you'll need to take into account.
#
# First, while MNIST were 28x28 monochome images (1 color channel), CIFAR are 32x32 color images (3 color channels).
#
# Second, MNIST images are simple, containing just the object, centered in the image, with no background. CIFAR ones can have the object with a background -- for example airplanes might have a cloudy sky behind them! As such you should expect your accuracy to be a bit lower.
#
# We start by setting up the problem for you.

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# We then definte some of the model for you but leave most of it for you to fill in!
#
# *A hint: your model may want to learn some high level features and then classify them.*

# %%
FIRST_LAYER = layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3))
HIDDEN_LAYER_TYPE_1 = layers.MaxPooling2D((2,2))
HIDDEN_LAYER_TYPE_2 = layers.Conv2D(64, (3,3), activation='relu')
HIDDEN_LAYER_TYPE_3 = layers.MaxPooling2D((2,2))
HIDDEN_LAYER_TYPE_4 = layers.Conv2D(64, (3,3), activation='relu')
HIDDEN_LAYER_TYPE_5 = layers.Dense(64, activation='relu')
LAST_LAYER = layers.Dense(10, activation='softmax')


model = models.Sequential([
       FIRST_LAYER,
       HIDDEN_LAYER_TYPE_1,
       HIDDEN_LAYER_TYPE_2,
       HIDDEN_LAYER_TYPE_3,
       HIDDEN_LAYER_TYPE_4,
       layers.Flatten(),
       HIDDEN_LAYER_TYPE_5,
       LAST_LAYER,
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# You then need to define loss function. And you can then train your model. Once training is done you'll see a plot of training and validation accuracy. You'll know you have a reasonable model with a reasonable loss funciton if your final training accuracy ends up in the 70s (or possibly higher).
#
# *A hint: your model may want to learn different categories.*

# %%
LOSS = 'sparse_categorical_crossentropy'
NUM_EPOCHS = 20 #You can change this value if you like to experiment with it to get better accuracy

# Compile the model
model.compile(optimizer='sgd',
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.1793 - loss: 2.1707 - val_accuracy: 0.2221 - val_loss: 2.2201
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.3713 - loss: 1.7446 - val_accuracy: 0.4151 - val_loss: 1.6176
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4544 - loss: 1.5114 - val_accuracy: 0.4976 - val_loss: 1.3812
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5121 - loss: 1.3738 - val_accuracy: 0.5261 - val_loss: 1.3316
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5447 - loss: 1.2863 - val_accuracy: 0.5356 - val_loss: 1.3213
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5738 - loss: 1.2081 - val_accuracy: 0.5604 - val_loss: 1.2350
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5962 - loss: 1.1484 - val_accuracy: 0.5968 - val_loss: 1.1433
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6232 - loss: 1.0814 - val_accuracy: 0.5981 - val_loss: 1.1186
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6376 - loss: 1.0362 - val_accuracy: 0.6317 - val_loss: 1.0433
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6581 - loss: 0.9772 - val_accuracy: 0.6320 - val_loss: 1.0276
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6749 - loss: 0.9390 - val_accuracy: 0.6433 - val_loss: 1.0214
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6860 - loss: 0.8980 - val_accuracy: 0.6628 - val_loss: 0.9574
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6981 - loss: 0.8615 - val_accuracy: 0.6662 - val_loss: 0.9652
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7103 - loss: 0.8399 - val_accuracy: 0.6693 - val_loss: 0.9583
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7170 - loss: 0.8041 - val_accuracy: 0.6729 - val_loss: 0.9402
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7299 - loss: 0.7780 - val_accuracy: 0.6914 - val_loss: 0.8912
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7373 - loss: 0.7523 - val_accuracy: 0.6821 - val_loss: 0.9359
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7448 - loss: 0.7330 - val_accuracy: 0.6762 - val_loss: 0.9370
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7577 - loss: 0.6979 - val_accuracy: 0.6462 - val_loss: 1.0461
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7666 - loss: 0.6734 - val_accuracy: 0.6478 - val_loss: 1.0323

# %% [markdown]
# Finally, pick a better optimizer. And re-train your model. You'll know you have a reasonable model with a reasonable loss funciton and optimizer if your final training accuracy ends up in the 80s (or possibly higher).
#
# *A hint: your model may want to learn adaptively.*

# %%
OPTIMIZER = 'adam'

# Compile the model
model.compile(optimizer=OPTIMIZER,
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6983 - loss: 0.8653 - val_accuracy: 0.6810 - val_loss: 0.9350
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7312 - loss: 0.7705 - val_accuracy: 0.6982 - val_loss: 0.8749
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7588 - loss: 0.6758 - val_accuracy: 0.7125 - val_loss: 0.8391
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7914 - loss: 0.5982 - val_accuracy: 0.7067 - val_loss: 0.9023
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8119 - loss: 0.5396 - val_accuracy: 0.7136 - val_loss: 0.8900
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8341 - loss: 0.4703 - val_accuracy: 0.6994 - val_loss: 0.9290
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8523 - loss: 0.4209 - val_accuracy: 0.7042 - val_loss: 0.9784
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8672 - loss: 0.3731 - val_accuracy: 0.7148 - val_loss: 0.9720
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8903 - loss: 0.3151 - val_accuracy: 0.7155 - val_loss: 1.0681
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8980 - loss: 0.2909 - val_accuracy: 0.6991 - val_loss: 1.1486
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9105 - loss: 0.2557 - val_accuracy: 0.6939 - val_loss: 1.2366
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9203 - loss: 0.2253 - val_accuracy: 0.7116 - val_loss: 1.2827
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9257 - loss: 0.2104 - val_accuracy: 0.6999 - val_loss: 1.3447
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9356 - loss: 0.1818 - val_accuracy: 0.7099 - val_loss: 1.3849
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9412 - loss: 0.1649 - val_accuracy: 0.6991 - val_loss: 1.5391
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9451 - loss: 0.1546 - val_accuracy: 0.7023 - val_loss: 1.5786
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9488 - loss: 0.1431 - val_accuracy: 0.6995 - val_loss: 1.7159
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9545 - loss: 0.1322 - val_accuracy: 0.6953 - val_loss: 1.6722
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9501 - loss: 0.1375 - val_accuracy: 0.6940 - val_loss: 1.7422
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9549 - loss: 0.1280 - val_accuracy: 0.6916 - val_loss: 1.8825
